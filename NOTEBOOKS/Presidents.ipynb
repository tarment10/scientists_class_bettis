# %%
import pandas as pd
df = pd.read_excel('http://qrc.depaul.edu/Excel_Files/Presidents.xls')

# %%
# %matplotlib inline
parties = df['Political Party'].value_counts()
parties
# Out:
# Republican               14
# Democrat                 13
# Democratic-Republican     4
# Whig                      2
# None                      1
# Federalist                1
# dtype: int64

# %%
parties.plot(kind="pie")

# %%
occupations = df['Occupation'].value_counts()
occupations
# Out:
# Lawyer             21
# Soldier             4
# Businessman         3
# Planter, Lawyer     1
# Engineer            1
# Author              1
# Educator            1
# Editor              1
# Actor               1
# Planter             1
# dtype: int64

# %%
occupations.plot(kind="pie")
